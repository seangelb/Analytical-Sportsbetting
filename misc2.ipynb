# %%
import algorithms
import data_clean
import pandas as pd
import numpy as np

# %%
df = data_clean.do(data_clean)
df = algorithms.ml_probabilities(df)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,

# %%
#df_scores = pd.read_csv('')

# %%
df_historic_win_data = data_clean.clean_data("spreadspoke_scores.csv", "nfl_teams.csv", "1990-9-10") #winners by spread since
df_historic_win_data.sort_values('schedule_date', ascending=False)
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 8003    2021-01-03             2020            17             False
# 7995    2021-01-03             2020            17             False
# 7988    2021-01-03             2020            17             False
# 7989    2021-01-03             2020            17             False
# 7990    2021-01-03             2020            17             False
# ...            ...              ...           ...               ...
# 9       1990-09-16             1990             2             False
# 10      1990-09-16             1990             2             False
# 11      1990-09-16             1990             2             False
# 12      1990-09-16             1990             2             False
# 0       1990-09-16             1990             2             False
#
#       score_home  score_away team_favorite_id  spread_favorite  \
# 8003         NaN         NaN              NaN              NaN
# 7995         NaN         NaN              NaN              NaN
# 7988         NaN         NaN              NaN              NaN
# 7989         NaN         NaN              NaN              NaN
# 7990         NaN         NaN              NaN              NaN
# ...          ...         ...              ...              ...
# 9           16.0        21.0              CIN             -3.0
# 10          26.0        13.0               SF             -5.0
# 11          13.0        17.0              LVR             -1.0
# 12          14.0        35.0              LAR             -3.0
# 0            7.0        28.0              NYG             -7.5
#
#      over_under_line                  stadium  stadium_neutral  \
# 8003             NaN    Raymond James Stadium            False
# 7995             NaN              NRG Stadium            False
# 7988             NaN            New Era Field            False
# 7989             NaN  Bank of America Stadium            False
# 7990             NaN            Soldier Field            False
# ...              ...                      ...              ...
# 9                 39         Qualcomm Stadium            False
# 10                44         Candlestick Park            False
# 11                36         Seattle Kingdome            False
# 12                47       Houlihan's Stadium            False
# 0                 37            Texas Stadium            False
#
#       weather_temperature  weather_wind_mph weather_humidity weather_detail  \
# 8003                  NaN               NaN              NaN            NaN
# 7995                 72.0               0.0              NaN           DOME
# 7988                  NaN               NaN              NaN            NaN
# 7989                  NaN               NaN              NaN            NaN
# 7990                  NaN               NaN              NaN            NaN
# ...                   ...               ...              ...            ...
# 9                    70.0               8.0               77            NaN
# 10                   63.0              16.0               71            NaN
# 11                   72.0               0.0              NaN           DOME
# 12                   83.0               9.0               79            NaN
# 0                    84.0               5.0               58            NaN
#
#      home away
# 8003   TB  ATL
# 7995  HOU  TEN
# 7988  BUF  MIA
# 7989  CAR   NO
# 7990  CHI   GB
# ...   ...  ...
# 9     LAC  CIN
# 10     SF  WAS
# 11    SEA  LVR
# 12     TB  LAR
# 0     DAL  NYG
#
# [8004 rows x 17 columns]

# %%
win_dict = algorithms.win_percent(df_historic_win_data)
win_dict
# Out:
# {-1.0: 0.502762,
#  -1.5: 0.505792,
#  -2.0: 0.590747,
#  -2.5: 0.578544,
#  -3.0: 0.678171,
#  -3.5: 0.741325,
#  -4.0: 0.762295,
#  -4.5: 0.784983,
#  -5.0: 0.828054,
#  -5.5: 0.837456,
#  -6.0: 0.845946,
#  -6.5: 0.848635,
#  -7.0: 0.885362,
#  -7.5: 0.926923,
#  -8.0: 0.883721,
#  -8.5: 0.918919,
#  -9.0: 0.923913,
#  -9.5: 0.9625,
#  -10.0: 0.947115,
#  -10.5: 0.969925,
#  -11.0: 1.0,
#  -11.5: 0.947368,
#  -12.0: 0.956522,
#  -12.5: 0.93617,
#  -13.0: 0.975,
#  -13.5: 0.968085,
#  -14.0: 0.986486,
#  -14.5: 0.977778,
#  -15.0: 1.0,
#  -15.5: 1.0,
#  -16.0: 1.0,
#  -16.5: 0.944444,
#  -17.0: 1.0,
#  -17.5: 1.0,
#  -18.0: 1.0,
#  -18.5: 1.0,
#  -19.0: 1.0,
#  -19.5: 1.0,
#  -20.0: 1.0,
#  -20.5: 1.0,
#  -21.0: 1.0,
#  -21.5: 1.0,
#  -22.5: 1.0,
#  -24.0: 1.0,
#  -24.5: 1.0,
#  -26.5: 1.0}

# %%
#df.sort_values('spread_favorite', ascending=False)

# %%
win_dict = algorithms.win_percent(df_historic_win_data)
df_ev = algorithms.plus_ev_games(win_dict, df, 0.05, -1.5)

# %%
df_ev[(df_ev['Bet_Type'] == "ARI") & (df_ev['EV'] < .1)].sort_values('EV', ascending=False).head(20)
# Out:
#     Bet_Type        EV away  away_ML home  home_ML  implied_win_away  \
# 116      ARI  0.074903  ARI    117.5  CHI   -136.0           0.45977
#
#      implied_win_home schedule_date  score_away  score_home  spread_favorite  \
# 116          0.576271    2009-11-08        41.0        21.0             -1.5
#
#     team_favorite_id  total_implied_prob
# 116              CHI            1.036041

# %%
df_ev[df_ev['spread_favorite'] >  -3]
# Out:
#      Bet_Type        EV away  away_ML home  home_ML  implied_win_away  \
# 116       ARI  0.104652  ARI    117.5  CHI   -136.0          0.459770
# 198       MIA  0.091956  MIA    115.0  JAX   -132.5          0.465116
# 230       HOU  0.066562  HOU    110.0  MIA   -127.5          0.476190
# 242       JAX  0.053863  JAX    107.5  CLE   -125.0          0.481928
# 346       DAL  0.061482  DAL    109.0  MIN   -124.5          0.478469
# 378       SEA  0.058943  SEA    108.5  LVR   -122.5          0.479616
# 439       SEA  0.061482   KC   -122.5  SEA    109.0          0.550562
# 501       LVR  0.081796  IND   -124.5  LVR    113.0          0.554566
# 535       PIT  0.053863  PIT    107.5  BAL   -122.5          0.481928
# 554       IND  0.064021  CLE   -123.5  IND    109.5          0.552573
# 777        KC  0.081796   KC    113.0  DEN   -127.5          0.469484
# 781       NYJ  0.051324  NYJ    107.0  MIA   -122.5          0.483092
# 1416      MIA  0.053863   GB   -125.0  MIA    107.5          0.555556
# 2200      CLE  0.053863  NYJ   -121.0  CLE    107.5          0.547511
# 2242      BUF  0.054057  LVR    105.5  BUF   -125.5          0.486618
# 2311      DAL  0.069101  WAS   -127.5  DAL    110.5          0.560440
# 2423       GB  0.061482  MIN   -123.0   GB    109.0          0.551570
# 2436       NO  0.066562   NO    110.0  ATL   -125.0          0.476190
# 2507      WAS  0.061482  DAL   -125.5  WAS    109.0          0.556541
# 2611      CLE  0.066562  CLE    110.0  DEN   -125.0          0.476190
# 2671      CAR  0.069101  LAR   -125.0  CAR    110.5          0.555556
# 2769      HOU  0.051324  HOU    107.0  IND   -122.5          0.483092
# 2910      BUF  0.058943  NYJ   -117.0  BUF    108.5          0.539171
# 2935       SF  0.066562   SF    110.0   KC   -126.0          0.476190
#
#       implied_win_home schedule_date  score_away  score_home  spread_favorite  \
# 116           0.576271    2009-11-08        41.0        21.0             -1.5
# 198           0.569892    2009-12-13        14.0        10.0             -1.5
# 230           0.560440    2009-12-27        27.0        20.0             -1.5
# 242           0.555556    2010-01-03        17.0        23.0             -1.5
# 346           0.554566    2010-10-17        21.0        24.0             -1.5
# 378           0.550562    2010-10-31         3.0        33.0             -1.5
# 439           0.478469    2010-11-28        42.0        24.0             -1.5
# 501           0.469484    2010-12-26        31.0        26.0             -1.5
# 535           0.550562    2011-09-11         7.0        35.0             -1.5
# 554           0.477327    2011-09-18        27.0        19.0             -1.5
# 777           0.560440    2012-01-01         7.0         3.0             -1.5
# 781           0.550562    2012-01-01        17.0        19.0             -1.5
# 1416          0.481928    2014-10-12        27.0        24.0             -1.5
# 2200          0.481928    2017-10-08        17.0        14.0             -1.5
# 2242          0.556541    2017-10-29        14.0        34.0             -2.5
# 2311          0.475059    2017-11-30        14.0        38.0             -1.5
# 2423          0.478469    2018-09-16        29.0        29.0             -1.5
# 2436          0.555556    2018-09-23        43.0        37.0             -1.5
# 2507          0.478469    2018-10-21        17.0        20.0             -1.5
# 2611          0.555556    2018-12-15        17.0        16.0             -1.5
# 2671          0.475059    2019-09-08        30.0        27.0             -1.5
# 2769          0.550562    2019-10-20        23.0        30.0             -1.5
# 2910          0.479616    2019-12-29        13.0         6.0             -1.5
# 2935          0.557522    2020-02-02        20.0        31.0             -1.5
#
#      team_favorite_id  total_implied_prob
# 116               CHI            1.036041
# 198               JAX            1.035008
# 230               MIA            1.036630
# 242               CLE            1.037484
# 346               MIN            1.033035
# 378               LVR            1.030178
# 439                KC            1.029031
# 501               IND            1.024050
# 535               BAL            1.032490
# 554               CLE            1.029900
# 777               DEN            1.029924
# 781               MIA            1.033654
# 1416               GB            1.037484
# 2200              NYJ            1.029439
# 2242              BUF            1.043159
# 2311              WAS            1.035499
# 2423              MIN            1.030039
# 2436              ATL            1.031746
# 2507              DAL            1.035010
# 2611              DEN            1.031746
# 2671              LAR            1.030615
# 2769              IND            1.033654
# 2910              NYJ            1.018787
# 2935               KC            1.033712
